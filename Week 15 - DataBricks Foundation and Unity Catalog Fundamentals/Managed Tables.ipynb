-- %%
SHOW TABLES;

-- %%
SHOW CATALOGS;

-- %%
SELECT CURRENT_METASTORE();

-- %%
create table if not exists study_databrikcs_upgrade_ws.default.students (
    id int,
    name string,
    score float
)

-- %%
insert into study_databrikcs_upgrade_ws.default.students values
    (1,'Arvi',90.5),
    (2,'Magesh',80.25),
    (3,'Pavi',85.5),
    (4,'Saashvik',95.75);

-- %%
select * from study_databrikcs_upgrade_ws.default.students

-- %%
describe detail study_databrikcs_upgrade_ws.default.students

-- %%
describe extended study_databrikcs_upgrade_ws.default.students

-- %%
create schema study_databrikcs_upgrade_ws.my_schema;

-- %%
create table study_databrikcs_upgrade_ws.my_schema.students (
    id int,
    name string,
    score float
);
insert into study_databrikcs_upgrade_ws.my_schema.students values
    (1,'Arvi',90.5),
    (2,'Magesh',80.25),
    (3,'Pavi',85.5),
    (4,'Saashvik',95.75);

-- %%
desc extended study_databrikcs_upgrade_ws.my_schema.students
