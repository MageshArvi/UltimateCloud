-- %%
create catalog my_catalog;

-- %%
create catalog my_catalog
managed location 'abfss://unitycatalog@databricksdemoarvi.dfs.core.windows.net/catalog'

-- %%
use catalog my_catalog;

-- %%
create schema my_catalog.studydb;

-- %%
create table my_catalog.studydb.students (
    id int,
    name string,
    score float
);
insert into my_catalog.studydb.students values(1, 'John', 80), (2, 'Mary', 90), (3, 'Mike', 70);

-- %%
select * from my_catalog.studydb.students;

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS adls_raw_catalog_ext_loc
URL 'abfss://unitycatalog@databricksdemoarvi.dfs.core.windows.net/adls_raw_catalog'
WITH (CREDENTIAL my_credentials)
COMMENT 'adls_ext_loc'
