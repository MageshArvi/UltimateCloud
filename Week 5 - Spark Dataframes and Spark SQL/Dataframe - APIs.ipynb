# %%
orders_df = spark.read.format("csv").option("header","true").option("inferSchema","true").load("dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv")
display(orders_df)

# %%
orders_df.show()

# %%
orders_df.printSchema()

# %%
trans_orders_df = orders_df.withColumnRenamed("order_status","status")

# %%
trans_orders_df.show()

# %%
from pyspark.sql.functions import *

# %%
trans_orders_date_df = orders_df.withColumn("order_date_new",to_date("order_date"))

# %%
trans_orders_date_df.printSchema()

# %%
display(trans_orders_date_df)
