# %%
orders_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
        .load("dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv")

# %%
orders_df.createOrReplaceTempView("orders")

# %%
spark.sql("create table sp_sql.orders_ext (order_id int, order_date string, customer_id int, order_status string) using csv location 'dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv'")

# %%
spark.sql("select * from sp_sql.orders_ext limit 5").show()
