# %%
orders_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
        .load("dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv")

# %%
orders_df.show()

# %%
orders_csv_df = spark.read.csv("dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv",header=True,inferSchema=True)

# %%
filtered_df = orders_csv_df.where("customer_id =11599")

# %%
filtered_df.show()

# %%
filtered_new_df = orders_csv_df.filter("customer_id =11599")
filtered_new_df.show()

# %%
orders_df.createOrReplaceTempView("orders")

# %%
sql_df = spark.sql("select * from orders where order_status = 'CLOSED'")

# %%
sql_df.show()
