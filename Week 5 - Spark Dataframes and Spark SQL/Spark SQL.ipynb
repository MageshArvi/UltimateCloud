# %%
orders_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
        .load("dbfs:/FileStore/shared_uploads/talk2mageshacc@outlook.com/orders_wh.csv")

# %%
orders_df.createOrReplaceTempView("orders")

# %%
spark.sql("create database if not exists sp_sql")

# %%
spark.sql("show databases").show()

# %%
spark.sql("show tables").show()

# %%
spark.sql("use sp_sql")

# %%
spark.sql("show tables").show()

# %%
spark.sql("create table sp_sql.orders (order_id int, order_date string, customer_id int, order_status string)")

# %%
spark.sql("show tables").show()

# %%
spark.sql("insert into sp_sql.orders select * from orders")

# %%
spark.sql("select * from sp_sql.orders limit 5").show()

# %%
spark.sql("desc extended sp_sql.orders").show(truncate=False)

# %%
spark.sql("drop table sp_sql.orders")

# %%
spark.sql("select * from sp_sql.orders").show()
