# %%
groceries_df = spark.read.csv("dbfs:/FileStore/datasets/groceries.csv",header="true")

# %%
groceries_df.show()

# %%
groceries_df.createOrReplaceTempView("groceries")

# %%
spark.sql("create database week5_assignment").show()

# %%
spark.sql("use week5_assignment")

# %%
spark.sql("create table week5_assignment.groceries (order_id int, location string, item string, order_date date, quantity string)")

# %%
spark.sql("select * from groceries").show()

# %%
spark.sql("show tables").show()

# %%
spark.sql("insert into week5_Assignment.groceries select * from groceries")
