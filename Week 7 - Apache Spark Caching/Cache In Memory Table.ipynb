# %%
orders_schema = 'order_id long, order_date date, customer_id long, order_status string'

# %%
orders_df = spark.read.format("csv").schema(orders_schema).load('abfss://unitycatalog@databricksstudysa.dfs.core.windows.net/catalog/orders_1gb.csv')

# %%
orders_df.distinct().count()

# %%
cached_df = orders_df.cache()

# %%
cached_df.distinct().count()

# %%
cached_df = orders_df.distinct().cache()

# %%
cached_df.count()

# %%
cached_df.unpersist()
