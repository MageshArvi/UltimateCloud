# %%
ddlSchema = "customer_id long, fullname struct<firstname:string,lastname:string>,city string"

# %%
cust_df = spark.read.json("dbfs:/FileStore/datasets/customer_nested/*",schema=ddlSchema)

# %%
cust_df.show()

# %%
cust_df.printSchema()

# %%
from pyspark.sql.types import *

# %%
struct_schema = StructType([
    StructField("customer_id",LongType()),
    StructField('fullname', StructType([
        StructField("firstname",StringType()),
        StructField("lastname",StringType())
    ])
    ),
    StructField("city",StringType())
])

# %%
cust_schema_df = spark.read.json("dbfs:/FileStore/datasets/customer_nested/*",schema=struct_schema)

# %%
cust_schema_df.show()

# %%
cust_schema_df.printSchema()
