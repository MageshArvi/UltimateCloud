# %%
orders_schema = "order_id long, order_date string, cust_id long, order_status string"

# %%
orders_df = spark.read.format("csv").schema(orders_schema).load("abfss://unitycatalog@databricksstudysa.dfs.core.windows.net/catalog/orders_1gb.csv")

# %%
orders_df.createOrReplaceTempView("orders")

# %%
spark.sql("select count(distinct(order_status)) from orders").show()

# %%
spark.conf.get('spark.sql.files.maxPartitionBytes')

# %%
max_partition_bytes_str = spark.conf.get('spark.sql.files.maxPartitionBytes'); max_partition_bytes = int(max_partition_bytes_str.rstrip('b'))
max_partition_mb = max_partition_bytes / (1024 * 1024)
display(max_partition_mb)
